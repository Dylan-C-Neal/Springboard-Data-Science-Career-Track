# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import pandas as pd
import numpy as np
# Load the pyplot collection of functions from matplotlib, as plt 
from matplotlib import pyplot as plt
# Import datetime as dt
from datetime import datetime as dt

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
# Used .info() and .head() to get a look at the raw data
properties.info()
properties.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302 entries, 0 to 301
# Data columns (total 49 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            301 non-null    datetime64[ns]
#  1   City of London        302 non-null    object
#  2   Barking & Dagenham    302 non-null    object
#  3   Barnet                302 non-null    object
#  4   Bexley                302 non-null    object
#  5   Brent                 302 non-null    object
#  6   Bromley               302 non-null    object
#  7   Camden                302 non-null    object
#  8   Croydon               302 non-null    object
#  9   Ealing                302 non-null    object
#  10  Enfield               302 non-null    object
#  11  Greenwich             302 non-null    object
#  12  Hackney               302 non-null    object
#  13  Hammersmith & Fulham  302 non-null    object
# ...

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
# Convert datetime column into M/Y format
properties.iloc[:,0] = properties.iloc[:,0].dt.strftime('%m/%Y')
### should have used to_datetime in place. Should use series operations rather
### than dataframe operations when possible

# %%
# Transpose data
properties = properties.transpose()

# %%
# Reset row indices
properties = properties.reset_index()

# %%
# Combine borough name with code into a single column
properties['index'] = properties.iloc[:, 0] + ': ' + properties.iloc[:, 1]
### should have used square brackets instead of .iloc
### columnwise operations are better off because it's what pandas does

# %%
# Delete redundant code column row
del properties[properties.columns[1]]

# %%
# Rename column indices
properties.columns = properties.iloc[0]
### properties['Unnamed: 0'] instead of .iloc

# %%
# Drop first row which was converted to column indices
properties = properties.drop(0)
properties
# Out:
# 0                               NaN  01/1995  02/1995  03/1995  04/1995  \
# 1         City of London: E09000001    91449  82202.8  79120.7  77101.2
# 2     Barking & Dagenham: E09000002  50460.2  51085.8    51269  53133.5
# 3                 Barnet: E09000003  93284.5  93190.2  92247.5  90762.9
# 4                 Bexley: E09000004  64958.1  64787.9  64367.5  64277.7
# 5                  Brent: E09000005  71306.6  72022.3  72015.8  72965.6
# 6                Bromley: E09000006  81671.5  81657.6  81449.3  81124.4
# 7                 Camden: E09000007   120933   119509   120282   120098
# 8                Croydon: E09000008  69158.2  68951.1  68712.4    68610
# 9                 Ealing: E09000009  79885.9  80897.1  81379.9  82188.9
# 10               Enfield: E09000010  72514.7  73155.2  72190.4  71442.9
# 11             Greenwich: E09000011  62300.1  60993.3  61377.8  61927.7
# 12               Hackney: E09000012  61296.5  63187.1  63593.3  65139.6
# ...

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
# Rename first column index
properties = properties.rename(columns={properties.columns[0]:'Borough'})

# %%
# Clean the formatting of Borough names
properties.iloc[:,0] = properties.iloc[:,0].str.title()
### .iloc shouldn't be used just for specifying a column. 
### Use df[] when possible

# %%
# Drop na
properties = properties.dropna()
properties
# Out:
# 0                           Borough  01/1995  02/1995  03/1995  04/1995  \
# 1         City Of London: E09000001    91449  82202.8  79120.7  77101.2
# 2     Barking & Dagenham: E09000002  50460.2  51085.8    51269  53133.5
# 3                 Barnet: E09000003  93284.5  93190.2  92247.5  90762.9
# 4                 Bexley: E09000004  64958.1  64787.9  64367.5  64277.7
# 5                  Brent: E09000005  71306.6  72022.3  72015.8  72965.6
# 6                Bromley: E09000006  81671.5  81657.6  81449.3  81124.4
# 7                 Camden: E09000007   120933   119509   120282   120098
# 8                Croydon: E09000008  69158.2  68951.1  68712.4    68610
# 9                 Ealing: E09000009  79885.9  80897.1  81379.9  82188.9
# 10               Enfield: E09000010  72514.7  73155.2  72190.4  71442.9
# 11             Greenwich: E09000011  62300.1  60993.3  61377.8  61927.7
# 12               Hackney: E09000012  61296.5  63187.1  63593.3  65139.6
# ...

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
# melt DataFrame to that Average Housing price and Date are contained in single columns
prop_melt = pd.melt(properties, id_vars=['Borough'])

# %%
# Rename columns appropriately
prop_melt = prop_melt.rename(columns={prop_melt.columns[1]:'Date', prop_melt.columns[2]:'Average Housing Price'})

# %%
# Set index to Borough
prop_melt = prop_melt.set_index(['Borough'])

# %%
# Convert Date column to datetime format
prop_melt['Date'] = pd.to_datetime(prop_melt['Date'], format='%m/%Y')

# %%
# Sort data by date so that it can be plotted easier later
prop_melt = prop_melt.sort_values(by='Date')
prop_melt
# Out:
#                                       Date Average Housing Price
# Borough
# City Of London: E09000001       1995-01-01                 91449
# Redbridge: E09000026            1995-01-01               72189.6
# Richmond Upon Thames: E09000027 1995-01-01                109326
# Southwark: E09000028            1995-01-01               67885.2
# Sutton: E09000029               1995-01-01                 71537
# ...                                    ...                   ...
# Hounslow: E09000018             2020-01-01                412352
# Islington: E09000019            2020-01-01                673418
# Kensington & Chelsea: E09000020 2020-01-01           1.17817e+06
# Enfield: E09000010              2020-01-01                391365
# England: E92000001              2020-01-01                247355
#
# [13545 rows x 2 columns]

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
# Describe Average Housing Price series to ensure dtype is float64
prop_melt['Average Housing Price'].describe()
# Out:
# count     13545.00000
# unique    13545.00000
# top       98302.97736
# freq          1.00000
# Name: Average Housing Price, dtype: float64

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
# List the unique indices. Compare vs Wikipedia page to identify ones to delete.
prop_melt.index.unique()
# Out:
# Index(['City Of London: E09000001', 'Redbridge: E09000026',
#        'Richmond Upon Thames: E09000027', 'Southwark: E09000028',
#        'Sutton: E09000029', 'Tower Hamlets: E09000030',
#        'Waltham Forest: E09000031', 'Wandsworth: E09000032',
#        'Westminster: E09000033', 'Outer London: E13000002',
#        'North East: E12000001', 'North West: E12000002',
#        'Yorks & The Humber: E12000003', 'East Midlands: E12000004',
#        'West Midlands: E12000005', 'East Of England: E12000006',
#        'London: E12000007', 'South East: E12000008', 'South West: E12000009',
#        'England: E92000001', 'Newham: E09000025', 'Merton: E09000024',
#        'Inner London: E13000001', 'Lambeth: E09000022', 'Lewisham: E09000023',
#        'Barnet: E09000003', 'Bexley: E09000004', 'Brent: E09000005',
#        'Bromley: E09000006', 'Camden: E09000007', 'Croydon: E09000008',
#        'Ealing: E09000009', 'Enfield: E09000010', 'Greenwich: E09000011',
# ...

# %%
# Drop list of unwanted indices
prop_melt = prop_melt.drop(['City Of London: E09000001', 'East Midlands: E12000004', 'East Of England: E12000006', 'England: E92000001', 'Inner London: E13000001', 'London: E12000007', 'North East: E12000001', 'North West: E12000002', 'Outer London: E13000002', 'South East: E12000008', 'South West: E12000009', 'West Midlands: E12000005', 'Yorks & The Humber: E12000003'])

# %%
# Confirm that there are correct number of indices
len(prop_melt.index.unique())
# Out:
# 32

# %%
# List final unique indices
prop_melt.index.unique()
# Out:
# Index(['Redbridge: E09000026', 'Richmond Upon Thames: E09000027',
#        'Southwark: E09000028', 'Sutton: E09000029', 'Tower Hamlets: E09000030',
#        'Waltham Forest: E09000031', 'Wandsworth: E09000032',
#        'Westminster: E09000033', 'Newham: E09000025', 'Merton: E09000024',
#        'Lambeth: E09000022', 'Lewisham: E09000023', 'Barnet: E09000003',
#        'Bexley: E09000004', 'Brent: E09000005', 'Bromley: E09000006',
#        'Camden: E09000007', 'Croydon: E09000008', 'Ealing: E09000009',
#        'Enfield: E09000010', 'Greenwich: E09000011',
#        'Barking & Dagenham: E09000002', 'Kingston Upon Thames: E09000021',
#        'Hammersmith & Fulham: E09000013', 'Haringey: E09000014',
#        'Harrow: E09000015', 'Havering: E09000016', 'Hillingdon: E09000017',
#        'Hounslow: E09000018', 'Islington: E09000019',
#        'Kensington & Chelsea: E09000020', 'Hackney: E09000012'],
#       dtype='object', name='Borough')

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
# Plot housing prices of Richmond Upon Thames
prop_melt.loc[prop_melt.index.unique()[1]].plot(x='Date', y='Average Housing Price', title=('Average Housing Price in ' + prop_melt.index.unique()[1]), legend=False)

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
# Extract year into its own column and rearrange column order
prop_melt['Year'] = pd.DatetimeIndex(prop_melt['Date']).year
prop_melt = prop_melt[['Date', 'Year', 'Average Housing Price']]

# %%
# Print head to verify correct
prop_melt.head()
# Out:
#                                       Date  Year Average Housing Price
# Borough
# Redbridge: E09000026            1995-01-01  1995               72189.6
# Richmond Upon Thames: E09000027 1995-01-01  1995                109326
# Southwark: E09000028            1995-01-01  1995               67885.2
# Sutton: E09000029               1995-01-01  1995                 71537
# Tower Hamlets: E09000030        1995-01-01  1995               59865.2

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
# Subset data into two sets: one for 1998 and one for 2018
p1998 = prop_melt.loc[prop_melt['Year'] == 1998]
p2018 = prop_melt.loc[prop_melt['Year'] == 2018]

# %%
# Extract average housing price for each borough and log in separate dictionaries for 1998 and 2018
dic1998 = {}
dic2018 = {}

for borough in p1998.index.unique():
    dic1998[borough] = p1998.loc[borough]['Average Housing Price'].mean()
    
for borough in p2018.index.unique():
    dic2018[borough] = p2018.loc[borough]['Average Housing Price'].mean()

# %%
# Combine dictionaries into a DateFrame
avgprice = pd.DataFrame({'1998 Price Average':pd.Series(dic1998), '2018 Price Average':pd.Series(dic2018)})

# %%
# Calculate price ratio of 1998 average price / 2018 average price and store in new column
avgprice['Price Ratio'] = avgprice['1998 Price Average'].divide(avgprice['2018 Price Average'])

# %%
# Calculate percent growth from 1998 to 2018 and store in new column
avgprice['Percent Growth'] = 1/avgprice['Price Ratio'] * 100
avgprice['Percent Growth'] = avgprice['Percent Growth'].round(2)

# %%
# Sort DataFrame by descending percent growth
avgprice = avgprice.sort_values(by='Percent Growth', ascending=False)

# %%
# Print DataFrame
avgprice
# Out:
#                                  1998 Price Average  2018 Price Average  \
# Hackney: E09000012                     87869.535804        5.446405e+05
# Waltham Forest: E09000031              75557.474132        4.408594e+05
# Southwark: E09000028                   91405.187779        5.042354e+05
# Lewisham: E09000023                    75539.051649        4.116290e+05
# Westminster: E09000033                190531.949942        1.020025e+06
# Newham: E09000025                      67671.270763        3.590225e+05
# Haringey: E09000014                   107419.850108        5.515606e+05
# Kensington & Chelsea: E09000020       268350.122142        1.363880e+06
# Lambeth: E09000022                    103179.118943        5.115364e+05
# Camden: E09000007                     170688.973933        8.424104e+05
# Barking & Dagenham: E09000002          60285.821083        2.951967e+05
# Brent: E09000005                      100692.590417        4.928454e+05
# ...

# %%
# Print DataFrame sorted by descending price in 2018
avgprice.sort_values(by='2018 Price Average', ascending=False)
# Out:
#                                  1998 Price Average  2018 Price Average  \
# Kensington & Chelsea: E09000020       268350.122142        1.363880e+06
# Westminster: E09000033                190531.949942        1.020025e+06
# Camden: E09000007                     170688.973933        8.424104e+05
# Hammersmith & Fulham: E09000013       175340.921250        7.255253e+05
# Richmond Upon Thames: E09000027       162956.066025        6.526654e+05
# Islington: E09000019                  134148.973300        6.498241e+05
# Wandsworth: E09000032                 125406.807233        5.966491e+05
# Haringey: E09000014                   107419.850108        5.515606e+05
# Hackney: E09000012                     87869.535804        5.446405e+05
# Barnet: E09000003                     122359.468033        5.332665e+05
# Merton: E09000024                     108049.855117        5.122939e+05
# Lambeth: E09000022                    103179.118943        5.115364e+05
# ...

# %%
# Describe Percent Growth column
avgprice['Percent Growth'].describe()
# Out:
# count     32.000000
# mean     469.795000
# std       57.073639
# min      397.640000
# 25%      423.702500
# 50%      468.400000
# 75%      498.897500
# max      619.830000
# Name: Percent Growth, dtype: float64

# %%
# Create a box plot of Percent Growth
avgprice['Percent Growth'].plot(kind='box', title='Percent Growth in Housing Price from 1998 to 2018 of London Boroughs')

# %%
# Find which borough experienced the highest average growth in price from 1998 to 2018
avgprice.loc[avgprice['Percent Growth'] == avgprice['Percent Growth'].max()]
# Out:
#                     1998 Price Average  2018 Price Average  Price Ratio  \
# Hackney: E09000012        87869.535804       544640.475027     0.161335
#
#                     Percent Growth
# Hackney: E09000012          619.83

# %%
# Find which borough experienced the lowest average growth in price from 1998 to 2018
avgprice.loc[avgprice['Percent Growth'] == avgprice['Percent Growth'].min()]
# Out:
#                      1998 Price Average  2018 Price Average  Price Ratio  \
# Hounslow: E09000018        99746.069682       396631.179788     0.251483
#
#                      Percent Growth
# Hounslow: E09000018          397.64

# %%
# Drop outlier and reanalyze
avgprice2 = avgprice.drop('Hackney: E09000012')

# %%
avgprice2['Percent Growth'].describe()
# Out:
# count     31.000000
# mean     464.955161
# std       50.906045
# min      397.640000
# 25%      422.505000
# 50%      462.670000
# 75%      494.660000
# max      583.480000
# Name: Percent Growth, dtype: float64

# %%
avgprice2['Percent Growth'].plot(kind='box', title='Percent Growth in Housing Price from 1998 to 2018 of London Boroughs without Outlier')

# %%
# After removing outlier, find which borough experienced the highest average growth in price from 1998 to 2018
avgprice2.loc[avgprice2['Percent Growth'] == avgprice2['Percent Growth'].max()]
# Out:
#                            1998 Price Average  2018 Price Average  \
# Waltham Forest: E09000031        75557.474132       440859.411128
#
#                            Price Ratio  Percent Growth
# Waltham Forest: E09000031     0.171387          583.48

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!

# %% [markdown]
# ### Response
#
# After analyzing the data, it was identified that the mean housing price growth for all boroughs in London from 1998 to 2018 was 470%. The median was 468%, and the standard deviation was 57%. The lowest growth in housing price was in Hounslow, with a growth rate of 398%. The highest growth in housing price was in Hackney, with a growth rate of 620%.
#
# By charting the percent growth data on a box plot, Hackney's growth rate was identified as an outlier. By dropping Hackney from the data set, the Percent Growth Rate values were recalculated as follows: mean = 465%, median = 463%, standard deviation = 51%. The highest growth rate after removing Hackney was identified Waltham Forest with a growth rate of 583%.
